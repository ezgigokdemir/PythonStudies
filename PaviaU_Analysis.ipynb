# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
import os
from PIL import Image
import scipy.io

# %%
def loadData():
    data_path = os.path.join(os.getcwd(),'data')
    data = sio.loadmat(os.path.join(data_path, 'PaviaU.mat'))    
    labels = sio.loadmat(os.path.join(data_path, 'PaviaU_gt.mat'))   
    return data, labels

# %%
data, labels = loadData()

# %%
data['paviaU'].shape
# Out:
# (610, 340, 103)

# %%
labels['paviaU_gt'].shape
# Out:
# (610, 340)

# %%
dataset_corrected = np.array(data['paviaU'])
dataset_gt = np.array(labels['paviaU_gt'])

dataset_corrected = np.swapaxes(dataset_corrected, 0, 1)
dataset_corrected = np.swapaxes(dataset_corrected, 0, 2)

# %%
dataset_corrected.shape
# Out:
# (103, 610, 340)

# %%
fig, ax = plt.subplots(1, 1)
ax.imshow(labels['paviaU_gt'], cmap='nipy_spectral')
